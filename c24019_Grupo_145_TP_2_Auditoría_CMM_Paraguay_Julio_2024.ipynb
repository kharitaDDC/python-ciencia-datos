# %% [markdown]
# <a href="https://colab.research.google.com/github/kharitaDDC/python-ciencia-datos/blob/main/c24019_Grupo_145_TP_2_Auditor%C3%ADa_CMM_Paraguay_Julio_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1bsJMympX53lfQMjvQalac1omcTEqCUUO">
#
# # **Auditoria CMM - PARAGUAY**
#
# ## **Datos de la comisión:** c24019 - TP 2
#  ###  **Grupo:** 145
#  ###  **Integrantes del equipo:**
#     David Della Croche  - DNI: 22.244.982
#     Matias Molina       - DNI: 31.994.247
#     Melina Vazquez      - DNI: 35.732.447
#     Victor Madedo       - DNI: 24.287.994

# %% [markdown]
# ## IMPORTO HOJAS:
#
#
# *   locations_profiles
# *   exports_to_Paraguay
# *   distributors_profiles
# *   sales_to_paraguay
#
#
#
# Sheet: "c24019 - Grupo 145 - TP 2 - Auditoría CMM - Paraguay -  Jul 2024" :
# https://docs.google.com/spreadsheets/d/1EnwIl9hSt0d3uCdqkByDDJ2rZ_QPoVet1gIvtiQk5ms/edit?usp=drive_link
#
# Sheet: "sales_in_Paraguay.xlsx"
# https://docs.google.com/spreadsheets/d/1fROe3BEny1EJ0RRTUpQRYPMQxUJkXHvL/edit?usp=drive_link

# %%
# URL de acceso a las hojas de un Gsheet como archivo CSV:
# Sheet: "c24019 - Grupo 145 - TP 2 - Datasets Auditoría CMM - Paraguay -  Julio 2024"
# https://docs.google.com/spreadsheets/d/1EnwIl9hSt0d3uCdqkByDDJ2rZ_QPoVet1gIvtiQk5ms/edit?usp=drive_link
# Carpeta Ggogle Drive TP2: https://drive.google.com/drive/folders/16V2HkV0dJD_VKhITf6KooVJqv_rZG1mZ?usp=drive_link
# hojas:
# locations_profiles
# exports_to_Paraguay
# distributors_profiles
# sales_in_paraguay

import pandas as pd


id_sheet   = "1EnwIl9hSt0d3uCdqkByDDJ2rZ_QPoVet1gIvtiQk5ms"

sheet_name = ""

url = f"https://docs.google.com/spreadsheets/d/{id_sheet}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %% [markdown]
# ## 1) -  **Verificación y LIMPIEZA DE DATOS**
#
#                 Verificar y eliminar nulos
#                 verificar si tiene filas duplicadas
#                 Eliminar columnas anomalas o innesesarias

# %% [markdown]
# ## **Hoja: locations_profiles**

# %%
# df_locations
sheet_name = "locations_profiles"
url = f"https://docs.google.com/spreadsheets/d/{id_sheet}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df_locations = pd.read_csv(url )
display(df_locations.head())
# Out:
#    PYid       id   location  department  \
# 0    71      NaN       Abaí     Caazapá
# 1   224      NaN     Acahay   Paraguarí
# 2   208      NaN    Alberdi    Ñeembucú
# 3   168      NaN  Alto Verá      Itapúa
# 4     7 $ 409.00      Altos  Cordillera
#
#                                           activities
# 0  food and beverage products manufacture, other ...
# 1  food and beverage products manufacture, other ...
# 2  food and beverage products manufacture, other ...
# 3  food and beverage products manufacture, other ...
# 4  agriculture, livestock, hunting and related, l...

# %%
# Tipos de datos en locations
df_locations.dtypes
# Out:
# PYid            int64
# id            float64
# location       object
# department     object
# activities     object
# dtype: object

# %%
#info
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PYid        272 non-null    int64
#  1   id          11 non-null     float64
#  2   location    264 non-null    object
#  3   department  271 non-null    object
#  4   activities  271 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 10.8+ KB

# %%
# El dataset "location_profile" se descarta por no tener datos que aporten algun datos util para el análisis y muchos datos anómalos

# %% [markdown]
# ## Hoja: exports_to_paraguay

# %%
sheet_name = "exports_to_Paraguay"
url = f"https://docs.google.com/spreadsheets/d/{id_sheet}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df_exports = pd.read_csv(url)
display(df_exports.head())
# Out:
#    distributor          Rubber           Brass           Vinyl  \
# 0       $ 1.53  $22.431.099,00  $36.031.577,00  $31.118.167,00
# 1       $ 1.55  $27.566.922,00  $21.996.538,00  $39.412.316,00
# 2       $ 1.67  $37.577.095,00  $41.457.655,00  $31.467.967,00
# 3     $ 364.00  $36.012.730,00  $41.667.692,00  $22.837.073,00
# 4     $ 920.00  $43.416.417,00  $36.290.780,00  $23.679.738,00
#
#           Granite           Stone           Brick        Aluminum  \
# 0  $21.322.223,00  $35.382.848,00  $35.280.292,00  $32.362.235,00
# 1  $25.681.987,00  $41.861.783,00  $22.408.742,00  $40.690.302,00
# 2  $37.577.926,00  $35.845.106,00  $42.953.168,00  $33.817.289,00
# 3  $29.288.200,00  $39.553.494,00  $33.513.588,00  $36.827.718,00
# 4  $21.183.706,00  $25.210.622,00  $30.864.041,00  $41.173.207,00
#
#             Glass         Plexiglass           Steel            Wood  \
# 0  $36.836.190,00  $9.440.858.902,00  $34.676.425,00  $31.862.742,00
# ...

# %%
# Ver estructura y tipos de datos y deteccion preliminar de Nulos
df_exports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   distributor  46 non-null     float64
#  1   Rubber       46 non-null     object
#  2   Brass        46 non-null     object
#  3   Vinyl        46 non-null     object
#  4   Granite      46 non-null     object
#  5   Stone        46 non-null     object
#  6   Brick        46 non-null     object
#  7   Aluminum     46 non-null     object
#  8   Glass        46 non-null     object
#  9   Plexiglass   46 non-null     object
#  10  Steel        46 non-null     object
#  11  Wood         46 non-null     object
#  12  Plastic      46 non-null     object
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  1 non-null      object
#  15  Columnas     1 non-null      object
# dtypes: float64(2), object(14)
# memory usage: 5.9+ KB

# %% [markdown]
# ### SE DETECTO:
# 1.   Columnas anomalas 13,14 y 15
# 2.   Columna (0) "distributor": pasar a int
# 3.   Columnas 1 a 12, eliminar símbolos "$ , ." y pasar a Float

# %%
#1- Eliminar las ultimas 3 columnas (13,14,15)
list_col_borrar = list(df_exports.columns[13:])
list_col_borrar

df_exports.drop(columns=list_col_borrar, axis = 1, inplace=True )

# %%
df_exports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   distributor  46 non-null     float64
#  1   Rubber       46 non-null     object
#  2   Brass        46 non-null     object
#  3   Vinyl        46 non-null     object
#  4   Granite      46 non-null     object
#  5   Stone        46 non-null     object
#  6   Brick        46 non-null     object
#  7   Aluminum     46 non-null     object
#  8   Glass        46 non-null     object
#  9   Plexiglass   46 non-null     object
#  10  Steel        46 non-null     object
#  11  Wood         46 non-null     object
#  12  Plastic      46 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 4.8+ KB

# %%
df_exports.tail()
# Out:
#     distributor          Rubber           Brass           Vinyl  \
# 41     $ 325.00  $25.138.331,00  $38.634.366,00  $35.724.628,00
# 42     $ 619.00  $41.761.417,00  $33.709.306,00  $27.497.587,00
# 43     $ 715.00  $20.880.116,00  $37.111.825,00  $34.422.161,00
# 44       $ 1.30  $34.050.845,00  $30.151.961,00  $26.956.027,00
# 45       $ 1.09  $35.580.430,00  $39.978.595,00  $32.046.855,00
#
#            Granite           Stone           Brick        Aluminum  \
# 41  $21.355.595,00  $42.958.842,00  $27.048.824,00  $32.985.225,00
# 42  $28.311.310,00  $21.683.294,00  $26.276.785,00  $32.530.973,00
# 43  $40.759.561,00  $26.050.968,00  $21.080.855,00  $21.443.932,00
# 44  $45.003.866,00  $23.879.569,00  $27.287.921,00  $44.733.537,00
# 45  $30.147.636,00  $36.212.747,00  $33.365.715,00  $35.482.192,00
#
#              Glass      Plexiglass           Steel            Wood  \
# 41  $33.904.151,00  $38.767.257,00  $31.216.833,00  $24.977.157,00
# ...

# %%
### 2- cambiar tipo de dato el id a int pero primero a str porque esta en float

df_exports["distributor"] = df_exports["distributor"].astype(str)
# Limpio simbolos
df_exports["distributor"] = df_exports["distributor"].str.replace(".0","")
df_exports["distributor"] = df_exports["distributor"].str.replace(".","")
df_exports["distributor"] = df_exports["distributor"].astype(int)
df_exports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   distributor  46 non-null     int64
#  1   Rubber       46 non-null     object
#  2   Brass        46 non-null     object
#  3   Vinyl        46 non-null     object
#  4   Granite      46 non-null     object
#  5   Stone        46 non-null     object
#  6   Brick        46 non-null     object
#  7   Aluminum     46 non-null     object
#  8   Glass        46 non-null     object
#  9   Plexiglass   46 non-null     object
#  10  Steel        46 non-null     object
#  11  Wood         46 non-null     object
#  12  Plastic      46 non-null     object
# dtypes: int64(1), object(12)
# memory usage: 4.8+ KB

# %%
df_exports.head()
# Out:
#    distributor          Rubber           Brass           Vinyl  \
# 0         1526  $22.431.099,00  $36.031.577,00  $31.118.167,00
# 1         1553  $27.566.922,00  $21.996.538,00  $39.412.316,00
# 2         1666  $37.577.095,00  $41.457.655,00  $31.467.967,00
# 3          364  $36.012.730,00  $41.667.692,00  $22.837.073,00
# 4          920  $43.416.417,00  $36.290.780,00  $23.679.738,00
#
#           Granite           Stone           Brick        Aluminum  \
# 0  $21.322.223,00  $35.382.848,00  $35.280.292,00  $32.362.235,00
# 1  $25.681.987,00  $41.861.783,00  $22.408.742,00  $40.690.302,00
# 2  $37.577.926,00  $35.845.106,00  $42.953.168,00  $33.817.289,00
# 3  $29.288.200,00  $39.553.494,00  $33.513.588,00  $36.827.718,00
# 4  $21.183.706,00  $25.210.622,00  $30.864.041,00  $41.173.207,00
#
#             Glass         Plexiglass           Steel            Wood  \
# 0  $36.836.190,00  $9.440.858.902,00  $34.676.425,00  $31.862.742,00
# ...

# %%
# Verifico si tiene nulos
df_exports["distributor"].isna().sum()
# Out:
# 0

# %%
#verifico si tiene duplicados
df_exports.duplicated().sum()
# Out:
# 2

# %%
#compruebo los duplicados
df_exports[df_exports.duplicated(keep='first') ]
# Out:
#     distributor          Rubber           Brass           Vinyl  \
# 19         1169  $38.180.046,00  $28.960.197,00  $38.400.970,00
# 41          325  $25.138.331,00  $38.634.366,00  $35.724.628,00
#
#            Granite           Stone            Brick        Aluminum  \
# 19  $23.646.886,00  $39.383.770,00  $122.710.022,00  $39.875.739,00
# 41  $21.355.595,00  $42.958.842,00   $27.048.824,00  $32.985.225,00
#
#              Glass      Plexiglass           Steel            Wood  \
# 19  $29.282.534,00  $38.309.291,00  $40.723.171,00  $27.897.700,00
# 41  $33.904.151,00  $38.767.257,00  $31.216.833,00  $24.977.157,00
#
#            Plastic
# 19  $23.071.801,00
# 41  $39.193.942,00

# %%
# obtengo el id de los duplicados
duplicated_rows = df_exports[df_exports.duplicated(keep='first')]
duplicated_rows
# Out:
#     distributor          Rubber           Brass           Vinyl  \
# 19         1169  $38.180.046,00  $28.960.197,00  $38.400.970,00
# 41          325  $25.138.331,00  $38.634.366,00  $35.724.628,00
#
#            Granite           Stone            Brick        Aluminum  \
# 19  $23.646.886,00  $39.383.770,00  $122.710.022,00  $39.875.739,00
# 41  $21.355.595,00  $42.958.842,00   $27.048.824,00  $32.985.225,00
#
#              Glass      Plexiglass           Steel            Wood  \
# 19  $29.282.534,00  $38.309.291,00  $40.723.171,00  $27.897.700,00
# 41  $33.904.151,00  $38.767.257,00  $31.216.833,00  $24.977.157,00
#
#            Plastic
# 19  $23.071.801,00
# 41  $39.193.942,00

# %%
# Obtener los id distributor duplicados en una lista
id_duplicados = duplicated_rows['distributor'].index.tolist()
id_duplicados
# Out:
# [19, 41]

# %%
# Elimino indices duplicados

df_exports.drop(id_duplicados, axis=0, inplace=True)

# %%
#verifico si tiene duplicados
df_exports.duplicated().sum()
# Out:
# 0

# %%
# CREO Lista de columnas df_exports
#list_col = list(df.columns[1:10])

list_col = list(df_exports.columns[1:13])
list_col
# Out:
# ['Rubber',
#  'Brass',
#  'Vinyl',
#  'Granite',
#  'Stone',
#  'Brick',
#  'Aluminum',
#  'Glass',
#  'Plexiglass',
#  'Steel',
#  'Wood',
#  'Plastic']

# %%
# Limpio simbolos, Primero los "$", 2do  los "." , 3ro reemplazo "," por "."
# Comas por puntos, no al revez , python trabaja asi los numeros, con punto decimal
for col in list_col:
  df_exports[col] = df_exports[col].str.replace("$","")
  df_exports[col] = df_exports[col].str.replace(".","")
  df_exports[col] = df_exports[col].str.replace(",",".")
df_exports.head()
# Out:
#    distributor       Rubber        Brass        Vinyl      Granite  \
# 0         1526  22431099.00  36031577.00  31118167.00  21322223.00
# 1         1553  27566922.00  21996538.00  39412316.00  25681987.00
# 2         1666  37577095.00  41457655.00  31467967.00  37577926.00
# 3          364  36012730.00  41667692.00  22837073.00  29288200.00
# 4          920  43416417.00  36290780.00  23679738.00  21183706.00
#
#          Stone        Brick     Aluminum        Glass     Plexiglass  \
# 0  35382848.00  35280292.00  32362235.00  36836190.00  9440858902.00
# 1  41861783.00  22408742.00  40690302.00  37958885.00  8726744768.00
# 2  35845106.00  42953168.00  33817289.00  41602183.00  1223232055.00
# 3  39553494.00  33513588.00  36827718.00  29669764.00    44858747.00
# 4  25210622.00  30864041.00  41173207.00  36719169.00    43893114.00
#
#          Steel         Wood      Plastic
# 0  34676425.00  31862742.00  32588556.00
# 1  26472020.00  27403955.00  37881851.00
# ...

# %%
# PASAR a "float" Las columnas de productos
for col in list_col:
  df_exports[col] = df_exports[col].astype(float)


#df['id pais'] = df['id pais'].astype(int)
df_exports.dtypes
# Out:
# distributor      int64
# Rubber         float64
# Brass          float64
# Vinyl          float64
# Granite        float64
# Stone          float64
# Brick          float64
# Aluminum       float64
# Glass          float64
# Plexiglass     float64
# Steel          float64
# Wood           float64
# Plastic        float64
# dtype: object

# %%
# Seteo para mejorar las visualizaciones
# lambda x: '{:,.2f}'
pd.options.display.float_format = "{:.2f}".format   # Formatea a 2 decimales y signo $
#cambiar el formato de display para que elñ cogigo antrior se modifique para que no muestre notacion cientifica

# %%
df_exports.head()
# Out:
#    distributor      Rubber       Brass       Vinyl     Granite       Stone  \
# 0         1526 22431099.00 36031577.00 31118167.00 21322223.00 35382848.00
# 1         1553 27566922.00 21996538.00 39412316.00 25681987.00 41861783.00
# 2         1666 37577095.00 41457655.00 31467967.00 37577926.00 35845106.00
# 3          364 36012730.00 41667692.00 22837073.00 29288200.00 39553494.00
# 4          920 43416417.00 36290780.00 23679738.00 21183706.00 25210622.00
#
#         Brick    Aluminum       Glass    Plexiglass       Steel        Wood  \
# 0 35280292.00 32362235.00 36836190.00 9440858902.00 34676425.00 31862742.00
# 1 22408742.00 40690302.00 37958885.00 8726744768.00 26472020.00 27403955.00
# 2 42953168.00 33817289.00 41602183.00 1223232055.00 30599951.00 40514747.00
# 3 33513588.00 36827718.00 29669764.00   44858747.00 26820925.00 20797348.00
# 4 30864041.00 41173207.00 36719169.00   43893114.00 22575455.00 21351499.00
#
#       Plastic
# 0 32588556.00
# 1 37881851.00
# ...

# %% [markdown]
# ### **Hoja: "distributors_profiles"**

# %%
sheet_name = "distributors_profiles"
url = f"https://docs.google.com/spreadsheets/d/{id_sheet}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df_distributors = pd.read_csv(url)
display(df_distributors.head(10))
# Out:
#       id                     distributor  \
# 0 565.00                 Abernathy-Hayes
# 1   1.38                  Balistreri LLC
# 2   1.18               Brekke-Stiedemann
# 3   1.53                     Collins LLC
# 4  29.00                   Cummings-Ward
# 5   1.05     Cummings, Kemmer and Walker
# 6   1.09         Davis, Kiehn and Heller
# 7 920.00      Denesik, Schmidt and Wyman
# 8   1.06  Feil, MacGyver and Schamberger
# 9    NaN                             NaN
#
#                               distributor activities  \
# 0  construction materials import/distribution, ir...
# 1  construction materials import/distribution, si...
# 2         construction materials import/distribution
# 3         construction materials import/distribution
# 4  construction materials import/distribution, ir...
# 5  construction materials import/distribution, co...
# 6  construction materials import/distribution, ne...
# 7  construction materials import/distribution, zi...
# ...

# %%
df_distributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                44 non-null     float64
#  1   distributor                       44 non-null     object
#  2   distributor activities            44 non-null     object
#  3   years in the construction market  46 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.6+ KB

# %%
df_distributors.duplicated().sum()
# Out:
# 1

# %% [markdown]
# ### SE DETECTO
#
# 1.   Hay valores nulos y duplicados
# 2.   El formato del id dstribuidor esta mal, hay que procesarlo para que sea int

# %%
df_distributors['id'].isna().sum()
#df.drop([2, 3], axis=0, inplace=True)
# Out:
# 2

# %%
#df_distributors[df_distributors["id"] == "920.0"]
df_distributors[df_distributors["id"].duplicated(keep=False) ]
# Out:
#     id distributor distributor activities  years in the construction market
# 9  NaN         NaN                    NaN                                 0
# 32 NaN         NaN                    NaN                                 0

# %%
duplicated_rows = df_distributors[df_distributors.duplicated(keep=False)]
print("Registros duplicados:")
print(duplicated_rows)
# Obtener los id de país duplicados en una lista
id_duplicados = duplicated_rows['id'].tolist()

print("Ids de país duplicados:", id_duplicados)
# Out:
# Registros duplicados:
#     id distributor distributor activities  years in the construction market
# 9  NaN         NaN                    NaN                                 0
# 32 NaN         NaN                    NaN                                 0
# Ids de país duplicados: [nan, nan]

# %%
# Obtener los índices de las filas con valores nulos
indices_con_nan = df_distributors[df_distributors.isna().any(axis=1)].index.tolist()
print("Índices de las filas con valores nulos:", indices_con_nan)
# Out:
# Índices de las filas con valores nulos: [9, 32]

# %%
# Elimino indices con NaN

df_distributors.drop(indices_con_nan, axis=0, inplace=True)

# %% [markdown]
# ### Verficaciones

# %%
# Verifico si se eliminaron los nulos
df_distributors['id'].isna().sum()
# Out:
# 0

# %%
df_distributors.duplicated().sum()
# Out:
# 0

# %%
#df_distributors.drop_duplicates(inplace=True)
#df_distributors
df_distributors.head()
# Out:
#       id        distributor  \
# 0 565.00    Abernathy-Hayes
# 1   1.38     Balistreri LLC
# 2   1.18  Brekke-Stiedemann
# 3   1.53        Collins LLC
# 4  29.00      Cummings-Ward
#
#                               distributor activities  \
# 0  construction materials import/distribution, ir...
# 1  construction materials import/distribution, si...
# 2         construction materials import/distribution
# 3         construction materials import/distribution
# 4  construction materials import/distribution, ir...
#
#    years in the construction market
# 0                                15
# 1                                22
# 2                                13
# 3                                12
# 4                                23

# %%
df_distributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                44 non-null     float64
#  1   distributor                       44 non-null     object
#  2   distributor activities            44 non-null     object
#  3   years in the construction market  44 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
### cambiar tipo de dato el id a int pero primero a str porque esta en float

df_distributors["id"] = df_distributors["id"].astype(str)
df_distributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                44 non-null     object
#  1   distributor                       44 non-null     object
#  2   distributor activities            44 non-null     object
#  3   years in the construction market  44 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
# Limpieza y cambio a tipo int
df_distributors['id'] = df_distributors['id'].str.replace(".0","")
df_distributors['id'] = df_distributors['id'].str.replace(".","")

df_distributors['id'] = df_distributors['id'].astype(int)

# %%
df_distributors.head()
# Out:
#      id        distributor                             distributor activities  \
# 0   565    Abernathy-Hayes  construction materials import/distribution, ir...
# 1  1384     Balistreri LLC  construction materials import/distribution, si...
# 2  1183  Brekke-Stiedemann         construction materials import/distribution
# 3  1526        Collins LLC         construction materials import/distribution
# 4    29      Cummings-Ward  construction materials import/distribution, ir...
#
#    years in the construction market
# 0                                15
# 1                                22
# 2                                13
# 3                                12
# 4                                23

# %%
# verifico el tipo de datos este correcto
df_distributors.dtypes
# Out:
# id                                   int64
# distributor                         object
# distributor activities              object
# years in the construction market     int64
# dtype: object

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# ### HOJA: "sales_in_paraguay"

# %%
id_sheet= "1fROe3BEny1EJ0RRTUpQRYPMQxUJkXHvL"
sheet_name = "sales_in_paraguay"
url = f"https://docs.google.com/spreadsheets/d/{id_sheet}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df_sales = pd.read_csv(url )
display(df_sales.head())
# Out:
#    distributor          Rubber           Brass           Vinyl  \
# 0       583.00  $54.510.203,61  $45.268.636,86  $51.579.748,25
# 1      1104.00  $32.438.788,20  $25.837.100,49  $36.603.264,50
# 2      1384.00  $21.780.180,58  $78.927.599,01  $25.837.100,49
# 3       379.00  $79.358.855,35  $90.185.311,22  $45.268.636,86
# 4      1599.00  $11.758.005,07  $21.780.180,58  $57.187.306,41
#
#           Granite           Stone  Brick        Aluminum           Glass  \
# 0  $21.780.180,58  $26.576.776,52  $0,00  $55.872.547,77  $18.050.385,12
# 1  $21.883.374,92   $1.473.437,08  $0,00  $46.239.695,30  $33.102.840,61
# 2  $33.102.840,61  $51.579.748,25  $0,00  $21.883.374,92  $78.927.599,01
# 3  $54.510.203,61  $59.358.855,35  $0,00  $79.358.855,35  $32.067.534,68
# 4   $9.945.371,16  $32.067.534,68  $0,00  $53.172.624,14  $57.187.306,41
#
#           Plexiglass      Steel            Wood      Plastic
# 0    $178.927.599,01  $2.788,80  $54.510.203,61   $20.982,80
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   distributor  44 non-null     float64
#  1   Rubber       45 non-null     object
#  2   Brass        45 non-null     object
#  3   Vinyl        45 non-null     object
#  4   Granite      45 non-null     object
#  5   Stone        45 non-null     object
#  6   Brick        45 non-null     object
#  7   Aluminum     45 non-null     object
#  8   Glass        45 non-null     object
#  9   Plexiglass   45 non-null     object
#  10  Steel        45 non-null     object
#  11  Wood         45 non-null     object
#  12  Plastic      45 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 4.7+ KB

# %% [markdown]
# # Limpieza datos
# ## Tabla:
# * df_sales    :
#                 Verificar y eliminar nulos
#                 verificar si tiene filas duplicadas
#                 limpar simbolos "$", y "," por "."
#                 Cambiar a tipo de dato float

# %%
# Verifico nulos
df_sales['distributor'].isna().sum()
# Out:
# 1

# %%
# Obtener los índices de las filas con valores nulos
indices_con_nan = df_sales[df_sales.isna().any(axis=1)].index.tolist()
print("\nÍndices de las filas con valores nulos:", indices_con_nan)
# Out:
# Índices de las filas con valores nulos: [44]

# %%
#fila  con inice_con_nan
df_sales.loc[indices_con_nan]
# Out:
#     distributor             Rubber              Brass              Vinyl  \
# 44          NaN  $1.680.453.941,34  $1.840.659.381,00  $1.912.589.120,61
#
#               Granite              Stone        Brick           Aluminum  \
# 44  $1.845.294.550,32  $1.651.519.395,68  $152.658,00  $2.163.832.570,90
#
#                 Glass          Plexiglass       Steel               Wood  \
# 44  $2.173.275.882,80  $25.974.040.668,75  $58.458,00  $1.930.565.060,49
#
#               Plastic
# 44  $2.047.338.174,36

# %%
# Elimino indices con NaN

df_sales.drop(indices_con_nan, axis=0, inplace=True)

# %%
#Verifico
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   distributor  44 non-null     float64
#  1   Rubber       44 non-null     object
#  2   Brass        44 non-null     object
#  3   Vinyl        44 non-null     object
#  4   Granite      44 non-null     object
#  5   Stone        44 non-null     object
#  6   Brick        44 non-null     object
#  7   Aluminum     44 non-null     object
#  8   Glass        44 non-null     object
#  9   Plexiglass   44 non-null     object
#  10  Steel        44 non-null     object
#  11  Wood         44 non-null     object
#  12  Plastic      44 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 4.6+ KB

# %%
# Verifico si hay nulos
df_sales['distributor'].isna().sum()
# Out:
# 0

# %%
#verifico si tiene duplicados
df_sales.duplicated().sum()
# Out:
# 0

# %%
# Paso la columna distributor a int
df_sales["distributor"] = df_sales["distributor"].astype(int)

# %%
df_sales.head()
# Out:
#    distributor          Rubber           Brass           Vinyl  \
# 0          583  $54.510.203,61  $45.268.636,86  $51.579.748,25
# 1         1104  $32.438.788,20  $25.837.100,49  $36.603.264,50
# 2         1384  $21.780.180,58  $78.927.599,01  $25.837.100,49
# 3          379  $79.358.855,35  $90.185.311,22  $45.268.636,86
# 4         1599  $11.758.005,07  $21.780.180,58  $57.187.306,41
#
#           Granite           Stone  Brick        Aluminum           Glass  \
# 0  $21.780.180,58  $26.576.776,52  $0,00  $55.872.547,77  $18.050.385,12
# 1  $21.883.374,92   $1.473.437,08  $0,00  $46.239.695,30  $33.102.840,61
# 2  $33.102.840,61  $51.579.748,25  $0,00  $21.883.374,92  $78.927.599,01
# 3  $54.510.203,61  $59.358.855,35  $0,00  $79.358.855,35  $32.067.534,68
# 4   $9.945.371,16  $32.067.534,68  $0,00  $53.172.624,14  $57.187.306,41
#
#           Plexiglass      Steel            Wood      Plastic
# 0    $178.927.599,01  $2.788,80  $54.510.203,61   $20.982,80
# ...

# %%
# CREO Lista de columnas df_sales

list_col = list(df_sales.columns[1:13])
list_col
# Out:
# ['Rubber',
#  'Brass',
#  'Vinyl',
#  'Granite',
#  'Stone',
#  'Brick',
#  'Aluminum',
#  'Glass',
#  'Plexiglass',
#  'Steel',
#  'Wood',
#  'Plastic']

# %%
# Limpiaza de simbolos en las columnas 1 a 12
for col in list_col:
  df_sales[col] = df_sales[col].str.replace("$","")
  df_sales[col] = df_sales[col].str.replace(".","")
  df_sales[col] = df_sales[col].str.replace(",",".")
df_sales.head()
# Out:
#    distributor       Rubber        Brass        Vinyl      Granite  \
# 0          583  54510203.61  45268636.86  51579748.25  21780180.58
# 1         1104  32438788.20  25837100.49  36603264.50  21883374.92
# 2         1384  21780180.58  78927599.01  25837100.49  33102840.61
# 3          379  79358855.35  90185311.22  45268636.86  54510203.61
# 4         1599  11758005.07  21780180.58  57187306.41   9945371.16
#
#          Stone Brick     Aluminum        Glass     Plexiglass    Steel  \
# 0  26576776.52  0.00  55872547.77  18050385.12   178927599.01  2788.80
# 1   1473437.08  0.00  46239695.30  33102840.61    35563624.11   599.01
# 2  51579748.25  0.00  21883374.92  78927599.01     1346769.34     0.00
# 3  59358855.35  0.00  79358855.35  32067534.68    53172624.14  2922.94
# 4  32067534.68  0.00  53172624.14  57187306.41  1155872547.77   203.61
#
#           Wood    Plastic
# 0  54510203.61   20982.80
# 1   9945371.16  187306.41
# 2  36603264.50  300838.58
# ...

# %%
# PASAR a "float"
for col in list_col:

  df_sales[col] = df_sales[col].astype(float)
  print(f"Columna: {col}", df_sales[col].dtypes )
print("\n")
# Out:
# Columna: Rubber float64
# Columna: Brass float64
# Columna: Vinyl float64
# Columna: Granite float64
# Columna: Stone float64
# Columna: Brick float64
# Columna: Aluminum float64
# Columna: Glass float64
# Columna: Plexiglass float64
# Columna: Steel float64
# Columna: Wood float64
# Columna: Plastic float64

# %%
#Verifico el tipo de datos quede bien
display( df_sales.dtypes)
# Out:
# distributor      int64
# Rubber         float64
# Brass          float64
# Vinyl          float64
# Granite        float64
# Stone          float64
# Brick          float64
# Aluminum       float64
# Glass          float64
# Plexiglass     float64
# Steel          float64
# Wood           float64
# Plastic        float64
# dtype: object

# %%
pd.options.display.float_format = "{:.2f}".format   # Formatea a 2 decimales

# %%
df_sales.head()
# Out:
#    distributor      Rubber       Brass       Vinyl     Granite       Stone  \
# 0          583 54510203.61 45268636.86 51579748.25 21780180.58 26576776.52
# 1         1104 32438788.20 25837100.49 36603264.50 21883374.92  1473437.08
# 2         1384 21780180.58 78927599.01 25837100.49 33102840.61 51579748.25
# 3          379 79358855.35 90185311.22 45268636.86 54510203.61 59358855.35
# 4         1599 11758005.07 21780180.58 57187306.41  9945371.16 32067534.68
#
#    Brick    Aluminum       Glass    Plexiglass   Steel        Wood   Plastic
# 0   0.00 55872547.77 18050385.12  178927599.01 2788.80 54510203.61  20982.80
# 1   0.00 46239695.30 33102840.61   35563624.11  599.01  9945371.16 187306.41
# 2   0.00 21883374.92 78927599.01    1346769.34    0.00 36603264.50 300838.58
# 3   0.00 79358855.35 32067534.68   53172624.14 2922.94 33102840.61 579748.25
# 4   0.00 53172624.14 57187306.41 1155872547.77  203.61 43512922.94 730734.07

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# #2) - MODELADO

# %%
# Necesito cambiar la columna "distributor" por "id distributor" en df_sales
df_sales.rename(columns={"distributor": "id distributor"}, inplace=True)
df_sales.head()
# Out:
#    id distributor      Rubber       Brass       Vinyl     Granite       Stone  \
# 0             583 54510203.61 45268636.86 51579748.25 21780180.58 26576776.52
# 1            1104 32438788.20 25837100.49 36603264.50 21883374.92  1473437.08
# 2            1384 21780180.58 78927599.01 25837100.49 33102840.61 51579748.25
# 3             379 79358855.35 90185311.22 45268636.86 54510203.61 59358855.35
# 4            1599 11758005.07 21780180.58 57187306.41  9945371.16 32067534.68
#
#    Brick    Aluminum       Glass    Plexiglass   Steel        Wood   Plastic
# 0   0.00 55872547.77 18050385.12  178927599.01 2788.80 54510203.61  20982.80
# 1   0.00 46239695.30 33102840.61   35563624.11  599.01  9945371.16 187306.41
# 2   0.00 21883374.92 78927599.01    1346769.34    0.00 36603264.50 300838.58
# 3   0.00 79358855.35 32067534.68   53172624.14 2922.94 33102840.61 579748.25
# 4   0.00 53172624.14 57187306.41 1155872547.77  203.61 43512922.94 730734.07

# %%
# Necesito cambiar la columna "distributor" por "id distributor" en df_exports
df_exports.rename(columns={"distributor": "id distributor"}, inplace=True)
df_exports.head()
# Out:
#    id distributor      Rubber       Brass       Vinyl     Granite       Stone  \
# 0            1526 22431099.00 36031577.00 31118167.00 21322223.00 35382848.00
# 1            1553 27566922.00 21996538.00 39412316.00 25681987.00 41861783.00
# 2            1666 37577095.00 41457655.00 31467967.00 37577926.00 35845106.00
# 3             364 36012730.00 41667692.00 22837073.00 29288200.00 39553494.00
# 4             920 43416417.00 36290780.00 23679738.00 21183706.00 25210622.00
#
#         Brick    Aluminum       Glass    Plexiglass       Steel        Wood  \
# 0 35280292.00 32362235.00 36836190.00 9440858902.00 34676425.00 31862742.00
# 1 22408742.00 40690302.00 37958885.00 8726744768.00 26472020.00 27403955.00
# 2 42953168.00 33817289.00 41602183.00 1223232055.00 30599951.00 40514747.00
# 3 33513588.00 36827718.00 29669764.00   44858747.00 26820925.00 20797348.00
# 4 30864041.00 41173207.00 36719169.00   43893114.00 22575455.00 21351499.00
#
#       Plastic
# 0 32588556.00
# ...

# %%
df_distributors.head()
# Out:
#      id        distributor                             distributor activities  \
# 0   565    Abernathy-Hayes  construction materials import/distribution, ir...
# 1  1384     Balistreri LLC  construction materials import/distribution, si...
# 2  1183  Brekke-Stiedemann         construction materials import/distribution
# 3  1526        Collins LLC         construction materials import/distribution
# 4    29      Cummings-Ward  construction materials import/distribution, ir...
#
#    years in the construction market
# 0                                15
# 1                                22
# 2                                13
# 3                                12
# 4                                23

# %%
# Necesito cambiar la columna "id" por "id distributor" df_distributors
df_distributors.rename(columns={"id": "id distributor"}, inplace=True)
df_distributors.head()
# Out:
#    id distributor        distributor  \
# 0             565    Abernathy-Hayes
# 1            1384     Balistreri LLC
# 2            1183  Brekke-Stiedemann
# 3            1526        Collins LLC
# 4              29      Cummings-Ward
#
#                               distributor activities  \
# 0  construction materials import/distribution, ir...
# 1  construction materials import/distribution, si...
# 2         construction materials import/distribution
# 3         construction materials import/distribution
# 4  construction materials import/distribution, ir...
#
#    years in the construction market
# 0                                15
# 1                                22
# 2                                13
# 3                                12
# 4                                23

# %%
#df_distributors[('id distributor','distributor')]

#quiero mostrar solo 'id distributor','distributor' del dataframe df_distributors
df_distributors[['id distributor','distributor']].head()
# Out:
#    id distributor        distributor
# 0             565    Abernathy-Hayes
# 1            1384     Balistreri LLC
# 2            1183  Brekke-Stiedemann
# 3            1526        Collins LLC
# 4              29      Cummings-Ward

# %% [markdown]
# ## MERGE sales y distributor
# Se combinan los datos de ventas por distribuidor

# %%
# merge entre df_exports y df_distributors y solo tomar las columnas "id distributor" y "distributor"
df_sales_distributors = df_sales.merge(df_distributors[['id distributor','distributor']], how= 'inner' , on='id distributor')
df_sales_distributors.head()

#df_exports_distributors = df_exports.merge(df_distributors, how= 'inner' , on='id distributor')
df_sales_distributors.head()
# Out:
#    id distributor      Rubber       Brass       Vinyl     Granite       Stone  \
# 0             583 54510203.61 45268636.86 51579748.25 21780180.58 26576776.52
# 1            1104 32438788.20 25837100.49 36603264.50 21883374.92  1473437.08
# 2            1384 21780180.58 78927599.01 25837100.49 33102840.61 51579748.25
# 3             379 79358855.35 90185311.22 45268636.86 54510203.61 59358855.35
# 4            1599 11758005.07 21780180.58 57187306.41  9945371.16 32067534.68
#
#    Brick    Aluminum       Glass    Plexiglass   Steel        Wood   Plastic  \
# 0   0.00 55872547.77 18050385.12  178927599.01 2788.80 54510203.61  20982.80
# 1   0.00 46239695.30 33102840.61   35563624.11  599.01  9945371.16 187306.41
# 2   0.00 21883374.92 78927599.01    1346769.34    0.00 36603264.50 300838.58
# 3   0.00 79358855.35 32067534.68   53172624.14 2922.94 33102840.61 579748.25
# 4   0.00 53172624.14 57187306.41 1155872547.77  203.61 43512922.94 730734.07
#
#        distributor
# ...

# %% [markdown]
# ## MERGE exports y distributor
#
# Se combinan los datos de Exportaciones por distribuidor

# %%
# merge entre df_exports y df_distributors y solo tomar las columnas "id distributor" y "distributor"
df_exports_distributors = df_exports.merge(df_distributors[['id distributor','distributor']], how= 'inner' , on='id distributor')
df_exports_distributors.head()

#df_exports_distributors = df_exports.merge(df_distributors, how= 'inner' , on='id distributor')
df_exports_distributors.head()
# Out:
#    id distributor      Rubber       Brass       Vinyl     Granite       Stone  \
# 0            1526 22431099.00 36031577.00 31118167.00 21322223.00 35382848.00
# 1            1553 27566922.00 21996538.00 39412316.00 25681987.00 41861783.00
# 2            1666 37577095.00 41457655.00 31467967.00 37577926.00 35845106.00
# 3             364 36012730.00 41667692.00 22837073.00 29288200.00 39553494.00
# 4             920 43416417.00 36290780.00 23679738.00 21183706.00 25210622.00
#
#         Brick    Aluminum       Glass    Plexiglass       Steel        Wood  \
# 0 35280292.00 32362235.00 36836190.00 9440858902.00 34676425.00 31862742.00
# 1 22408742.00 40690302.00 37958885.00 8726744768.00 26472020.00 27403955.00
# 2 42953168.00 33817289.00 41602183.00 1223232055.00 30599951.00 40514747.00
# 3 33513588.00 36827718.00 29669764.00   44858747.00 26820925.00 20797348.00
# 4 30864041.00 41173207.00 36719169.00   43893114.00 22575455.00 21351499.00
#
# ...

# %% [markdown]
# # **3) - Analisis de Datos**

# %%
import matplotlib.pyplot as plt

# %%
# Formateo
pd.options.display.float_format = "$ {:,.2f}".format   # Formatea a 2 decimales y signo $

# %% [markdown]
# # Procesos para analizar Ventas en Paraguay

# %%
list_col = list(df_sales_distributors.columns[1:13])
#list_col
#creo un nuevo dataframe con las columnas lista_col
df_ventas_distributors_productos = df_sales_distributors[list_col]
df_ventas_distributors_productos.head()
# Out:
#            Rubber           Brass           Vinyl         Granite  \
# 0 $ 54,510,203.61 $ 45,268,636.86 $ 51,579,748.25 $ 21,780,180.58
# 1 $ 32,438,788.20 $ 25,837,100.49 $ 36,603,264.50 $ 21,883,374.92
# 2 $ 21,780,180.58 $ 78,927,599.01 $ 25,837,100.49 $ 33,102,840.61
# 3 $ 79,358,855.35 $ 90,185,311.22 $ 45,268,636.86 $ 54,510,203.61
# 4 $ 11,758,005.07 $ 21,780,180.58 $ 57,187,306.41  $ 9,945,371.16
#
#             Stone  Brick        Aluminum           Glass         Plexiglass  \
# 0 $ 26,576,776.52 $ 0.00 $ 55,872,547.77 $ 18,050,385.12   $ 178,927,599.01
# 1  $ 1,473,437.08 $ 0.00 $ 46,239,695.30 $ 33,102,840.61    $ 35,563,624.11
# 2 $ 51,579,748.25 $ 0.00 $ 21,883,374.92 $ 78,927,599.01     $ 1,346,769.34
# 3 $ 59,358,855.35 $ 0.00 $ 79,358,855.35 $ 32,067,534.68    $ 53,172,624.14
# 4 $ 32,067,534.68 $ 0.00 $ 53,172,624.14 $ 57,187,306.41 $ 1,155,872,547.77
#
#        Steel            Wood      Plastic
# 0 $ 2,788.80 $ 54,510,203.61  $ 20,982.80
# ...

# %%
# Calculo el total de cada columna de producto

ventas_total = df_ventas_distributors_productos.sum(numeric_only=True)

ventas_total
# Out:
# Rubber        $ 1,421,294,421.00
# Brass         $ 1,484,604,114.16
# Vinyl         $ 1,650,956,688.66
# Granite       $ 1,585,120,861.70
# Stone         $ 1,477,568,397.99
# Brick               $ 129,646.00
# Aluminum      $ 1,865,725,213.72
# Glass         $ 1,889,619,939.26
# Plexiglass   $ 22,300,657,216.09
# Steel                $ 56,702.14
# Wood          $ 1,678,822,831.02
# Plastic       $ 1,855,088,444.67
# dtype: float64

# %%
# pasar ventas_total a dataframe y la primer columna sea el indice
#df_ventas_total = pd.DataFrame(ventas_total).reset_index()
df_ventas_total = pd.DataFrame(ventas_total, columns=['Total_ventas']).reset_index()
df_ventas_total
# Out:
#          index        Total_ventas
# 0       Rubber  $ 1,421,294,421.00
# 1        Brass  $ 1,484,604,114.16
# 2        Vinyl  $ 1,650,956,688.66
# 3      Granite  $ 1,585,120,861.70
# 4        Stone  $ 1,477,568,397.99
# 5        Brick        $ 129,646.00
# 6     Aluminum  $ 1,865,725,213.72
# 7        Glass  $ 1,889,619,939.26
# 8   Plexiglass $ 22,300,657,216.09
# 9        Steel         $ 56,702.14
# 10        Wood  $ 1,678,822,831.02
# 11     Plastic  $ 1,855,088,444.67

# %%
# cambiar el nombre de la columna "index" a "Producto"
df_ventas_total.rename(columns={"index": "Producto"}, inplace=True)
df_ventas_total.head()

# Transformar el valor de la columna Total_ventas a un valor legible dividienolo por 1 millon
df_ventas_total['Total_ventas'] = df_ventas_total['Total_ventas'] / 1000000
df_ventas_total
# Out:
#       Producto  Total_ventas
# 0       Rubber    $ 1,421.29
# 1        Brass    $ 1,484.60
# 2        Vinyl    $ 1,650.96
# 3      Granite    $ 1,585.12
# 4        Stone    $ 1,477.57
# 5        Brick        $ 0.13
# 6     Aluminum    $ 1,865.73
# 7        Glass    $ 1,889.62
# 8   Plexiglass   $ 22,300.66
# 9        Steel        $ 0.06
# 10        Wood    $ 1,678.82
# 11     Plastic    $ 1,855.09

# %% [markdown]
# *   Aqui ya se observa una discrepancia en las ventas de "Ladrillos"(Brick)  y "Acero"(Steel) con valores muy bajos

# %%
# Ordenamos de forma descendente y poder Observar los productos que menos ventas tengan
df_ventas_total.sort_values(by='Total_ventas', ascending=True)
# Out:
#       Producto  Total_ventas
# 9        Steel        $ 0.06
# 5        Brick        $ 0.13
# 0       Rubber    $ 1,421.29
# 4        Stone    $ 1,477.57
# 1        Brass    $ 1,484.60
# 3      Granite    $ 1,585.12
# 2        Vinyl    $ 1,650.96
# 10        Wood    $ 1,678.82
# 11     Plastic    $ 1,855.09
# 6     Aluminum    $ 1,865.73
# 7        Glass    $ 1,889.62
# 8   Plexiglass   $ 22,300.66

# %%
# df_ventas_total solo columnas Brick y Steel para observar con más detalle
df_ventas_filtrado_brick_steel = df_ventas_total[(df_ventas_total["Producto"] == "Brick") | (df_ventas_total["Producto"] == "Steel")]
df_ventas_filtrado_brick_steel
# Out:
#   Producto  Total_ventas
# 5    Brick        $ 0.13
# 9    Steel        $ 0.06

# %%
# Se Detecto bajas ventas de "Brick" (Ladrillos) y "Steel"(Acero)

# %% [markdown]
# #Procesos Para analizar Exportaciones en Paraguay

# %%
list_col = list(df_exports_distributors.columns[1:13])
#list_col
#creo un nuevo dataframe con las columnas lista_col
df_exportaciones_distributors_productos = df_exports_distributors[list_col]
df_exportaciones_distributors_productos.head()
# Out:
#            Rubber           Brass           Vinyl         Granite  \
# 0 $ 22,431,099.00 $ 36,031,577.00 $ 31,118,167.00 $ 21,322,223.00
# 1 $ 27,566,922.00 $ 21,996,538.00 $ 39,412,316.00 $ 25,681,987.00
# 2 $ 37,577,095.00 $ 41,457,655.00 $ 31,467,967.00 $ 37,577,926.00
# 3 $ 36,012,730.00 $ 41,667,692.00 $ 22,837,073.00 $ 29,288,200.00
# 4 $ 43,416,417.00 $ 36,290,780.00 $ 23,679,738.00 $ 21,183,706.00
#
#             Stone           Brick        Aluminum           Glass  \
# 0 $ 35,382,848.00 $ 35,280,292.00 $ 32,362,235.00 $ 36,836,190.00
# 1 $ 41,861,783.00 $ 22,408,742.00 $ 40,690,302.00 $ 37,958,885.00
# 2 $ 35,845,106.00 $ 42,953,168.00 $ 33,817,289.00 $ 41,602,183.00
# 3 $ 39,553,494.00 $ 33,513,588.00 $ 36,827,718.00 $ 29,669,764.00
# 4 $ 25,210,622.00 $ 30,864,041.00 $ 41,173,207.00 $ 36,719,169.00
#
#           Plexiglass           Steel            Wood         Plastic
# 0 $ 9,440,858,902.00 $ 34,676,425.00 $ 31,862,742.00 $ 32,588,556.00
# ...

# %%
# Calculo el total de cada columna de producto

exporta_total = df_exportaciones_distributors_productos.sum(numeric_only=True)

exporta_total
# Out:
# Rubber        $ 1,465,042,482.00
# Brass         $ 1,394,438,925.00
# Vinyl         $ 1,396,050,453.00
# Granite       $ 1,337,169,964.00
# Stone         $ 1,474,570,889.00
# Brick         $ 5,260,549,009.00
# Aluminum      $ 1,513,169,630.00
# Glass         $ 1,429,786,765.00
# Plexiglass   $ 20,779,232,535.00
# Steel        $ 13,652,930,026.00
# Wood          $ 1,409,171,577.00
# Plastic       $ 1,456,143,794.00
# dtype: float64

# %%
#Pasar exporta_total a dataframe y la primer columna sea el indice
#df_ventas_total = pd.DataFrame(exporta_total).reset_index()
df_exporta_total = pd.DataFrame(exporta_total, columns=['Total_Exports']).reset_index()
df_exporta_total
# Out:
#          index       Total_Exports
# 0       Rubber  $ 1,465,042,482.00
# 1        Brass  $ 1,394,438,925.00
# 2        Vinyl  $ 1,396,050,453.00
# 3      Granite  $ 1,337,169,964.00
# 4        Stone  $ 1,474,570,889.00
# 5        Brick  $ 5,260,549,009.00
# 6     Aluminum  $ 1,513,169,630.00
# 7        Glass  $ 1,429,786,765.00
# 8   Plexiglass $ 20,779,232,535.00
# 9        Steel $ 13,652,930,026.00
# 10        Wood  $ 1,409,171,577.00
# 11     Plastic  $ 1,456,143,794.00

# %%
# cambiar el nombre de la columna "index" a "Producto"
df_exporta_total.rename(columns={"index": "Producto"}, inplace=True)
df_exporta_total.head()

# Transformar el valor de la columna Total_ventas a un valor legible dividienolo por 1 millon
df_exporta_total['Total_Exports'] = df_exporta_total['Total_Exports'] / 1000000

# %%
# MUESTRO el TOTAL de EXPORTACIONES
display(df_exporta_total)
# Out:
#       Producto  Total_Exports
# 0       Rubber     $ 1,465.04
# 1        Brass     $ 1,394.44
# 2        Vinyl     $ 1,396.05
# 3      Granite     $ 1,337.17
# 4        Stone     $ 1,474.57
# 5        Brick     $ 5,260.55
# 6     Aluminum     $ 1,513.17
# 7        Glass     $ 1,429.79
# 8   Plexiglass    $ 20,779.23
# 9        Steel    $ 13,652.93
# 10        Wood     $ 1,409.17
# 11     Plastic     $ 1,456.14

# %%
# Ordeno de forma descendente
df_exporta_total.sort_values(by='Total_Exports', ascending=False)
# Out:
#       Producto  Total_Exports
# 8   Plexiglass    $ 20,779.23
# 9        Steel    $ 13,652.93
# 5        Brick     $ 5,260.55
# 6     Aluminum     $ 1,513.17
# 4        Stone     $ 1,474.57
# 0       Rubber     $ 1,465.04
# 11     Plastic     $ 1,456.14
# 7        Glass     $ 1,429.79
# 10        Wood     $ 1,409.17
# 2        Vinyl     $ 1,396.05
# 1        Brass     $ 1,394.44
# 3      Granite     $ 1,337.17

# %% [markdown]
# ### Analizo Exportaciones por distribuidores Teniendo en cuenta las bajas Ventas de Acero y Ladrillos

# %%
#agrupar por distribuidor la sumatoria de cada producto
df_exp_dist_brick_steel = df_exports_distributors[['distributor','Brick','Steel']].groupby('distributor').sum()

df_exp_dist_brick_steel
# Out:
#                                                Brick               Steel
# distributor
# Abernathy-Hayes                      $ 28,907,442.00     $ 22,252,637.00
# Balistreri LLC                       $ 39,745,929.00     $ 33,507,580.00
# Brekke-Stiedemann                    $ 30,154,265.00 $ 12,242,337,842.00
# Collins LLC                          $ 35,280,292.00     $ 34,676,425.00
# Cummings, Kemmer and Walker          $ 25,023,137.00     $ 31,000,153.00
# Cummings-Ward                        $ 34,340,349.00     $ 44,468,552.00
# Davis, Kiehn and Heller              $ 33,365,715.00     $ 31,214,082.00
# Denesik, Schmidt and Wyman           $ 30,864,041.00     $ 22,575,455.00
# Feil, MacGyver and Schamberger       $ 37,955,177.00     $ 38,093,914.00
# Gerlach Group                        $ 43,238,079.00     $ 32,970,603.00
# Goldner Inc                          $ 27,704,919.00     $ 30,902,218.00
# Grady, Kessler and Stokes            $ 25,843,761.00     $ 23,094,699.00
# ...

# %%
#El distributor que mas vendio Steel y Brick
df_exp_dist_brick_steel = pd.DataFrame(df_exp_dist_brick_steel).reset_index()

# %%
#mostrar Max solo de columna brick
df_exp_brick_max =  df_exp_dist_brick_steel[['distributor','Brick'] ][df_exp_dist_brick_steel['Brick']== df_exp_dist_brick_steel['Brick'].max()]
# filtrar el distributor donde steel = max
df_exp_steel_max = df_exp_dist_brick_steel[['distributor','Steel']][df_exp_dist_brick_steel['Steel'] == df_exp_dist_brick_steel['Steel'].max()]
#mostrar Max solo de columna brick
# df_exp_brick_min =  df_exp_dist_brick_steel[['distributor','Brick'] ][df_exp_dist_brick_steel['Brick']== df_exp_dist_brick_steel['Brick'].min()]
# filtrr el distributor donde steel = max
#df_exp_steel_min = df_exp_dist_brick_steel[['distributor','Steel']][df_exp_dist_brick_steel['Steel'] == df_exp_dist_brick_steel['Steel'].min()]

# %%
print("\b Distribuidor que exportó más ladrillos(Brick): \b")
display(df_exp_brick_max)
print("\b Distribuidor que exportó más Acero(Steel): \b")
display(df_exp_steel_max)
#print("\b Distribuidor que exportó menos ladrillos(Brick): \b")
#display(df_exp_brick_min)
#print("\b Distribuidor que exportó menos Acero(Steel): \b")
#display(df_exp_steel_min)
# Out:
#  Distribuidor que exportó más ladrillos(Brick):
#                      distributor              Brick
# 20  Kreiger, Leffler and Dibbert $ 1,643,078,851.00
#  Distribuidor que exportó más Acero(Steel):
#          distributor               Steel
# 2  Brekke-Stiedemann $ 12,242,337,842.00

# %% [markdown]
#   * Se exponen los dos distribuidores que mas exportaron hacia Paraguay Ladrillos y Acero

# %% [markdown]
# ## COMPARAMOS VENTAS vs EXPORTACIONES ordenando en forma descendente las exportaciones

# %%
# Hago un merge de df_exports_total y df_ventas_total
df_ventas_vs_exportaciones = pd.merge(df_ventas_total, df_exporta_total, on='Producto')
df_ventas_vs_exportaciones.head()
# Out:
#   Producto  Total_ventas  Total_Exports
# 0   Rubber    $ 1,421.29     $ 1,465.04
# 1    Brass    $ 1,484.60     $ 1,394.44
# 2    Vinyl    $ 1,650.96     $ 1,396.05
# 3  Granite    $ 1,585.12     $ 1,337.17
# 4    Stone    $ 1,477.57     $ 1,474.57

# %% [markdown]
# # **Tabla Comparativa:** Ventas Vs Exportaciones

# %%
# ordeno por columna Total_exports de forma descendente
df_ventas_vs_exportaciones_ordenado = df_ventas_vs_exportaciones.sort_values(by='Total_Exports', ascending=False)

# %%
# Comparamos Ventas contra Ingresos
df_ventas_vs_exportaciones_ordenado
# Out:
#       Producto  Total_ventas  Total_Exports
# 8   Plexiglass   $ 22,300.66    $ 20,779.23
# 9        Steel        $ 0.06    $ 13,652.93
# 5        Brick        $ 0.13     $ 5,260.55
# 6     Aluminum    $ 1,865.73     $ 1,513.17
# 4        Stone    $ 1,477.57     $ 1,474.57
# 0       Rubber    $ 1,421.29     $ 1,465.04
# 11     Plastic    $ 1,855.09     $ 1,456.14
# 7        Glass    $ 1,889.62     $ 1,429.79
# 10        Wood    $ 1,678.82     $ 1,409.17
# 2        Vinyl    $ 1,650.96     $ 1,396.05
# 1        Brass    $ 1,484.60     $ 1,394.44
# 3      Granite    $ 1,585.12     $ 1,337.17

# %% [markdown]
# ## - Analisis Preliminares y conclusiones
# * En la vista comparativa de Ventas vs Exportaciones observamos que es equitativa la venta con respecto a la exportación de productos pero no así en dos productos específicos, en 2 de ellos, Brick(Ladrillos) y Steel (Acero).
# *   Se detecta que en las Ventas vs Exportaciones, los productos "ladrillos" (Brick) y "Acero" (Steel), hay discrepancias notables entre las ventas casi nulas con respecto a las exportaciones.
# *   Se recomienda Auditar distribuidores en los movimientos en esos productos de ingresos y comercialización para la venta.

# %% [markdown]
# # 4) - GRAFICOS

# %%
#@title Total Ventas por Producto y Total de Exportaciones
#Gráfico de barras para visualizar el total de ventas por producto

fig, ax = plt.subplots(1, 2, figsize=(15, 6))
df_ventas_total.plot(kind='bar',x='Producto', y='Total_ventas', color='r', ax=ax[0])
ax[0].set_title('Total Ventas por Producto')
ax[0].set_xlabel('Producto')
ax[0].set_ylabel('Total Ventas (en Millones)')
ax[0].set_xticklabels(df_ventas_total['Producto'], rotation=45)
ax[0].grid(axis='both')
max_value = df_ventas_total["Total_ventas"].max()
ax[0].set_yticks(range(0, int(max_value) + 5000, 5000))
# Formateo del eje Y para mejor visualización
ax[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f'{x :,.0f}'))


#Gráfico de barras para visualizar el total de Exports por producto

df_exporta_total.plot(kind='bar',x='Producto', y='Total_Exports', color='b', ax=ax[1])
ax[1].set_title('Total Exportaciones por Producto')
ax[1].set_xlabel('Producto')
ax[1].set_ylabel('Total Exportaciones (en Millones)')
ax[1].set_xticklabels(df_ventas_total['Producto'], rotation=45)
ax[1].grid(axis='both')
max_value = df_exporta_total["Total_Exports"].max()
ax[1].set_yticks(range(0, int(max_value) + 5000, 5000))
# Formateo del eje Y para mejor visualización
ax[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f'{x :,.0f}'))


plt.tight_layout()
#plt.show()

# Crear el gráfico de líneas
plt.figure(figsize=(10, 6))

# Graficar Total_ventas
plt.plot(df_ventas_vs_exportaciones_ordenado["Producto"], df_ventas_vs_exportaciones_ordenado["Total_ventas"], color='b', marker='o', label='Total_ventas')

# Graficar Total_Exports
plt.plot(df_ventas_vs_exportaciones_ordenado["Producto"], df_ventas_vs_exportaciones_ordenado["Total_Exports"], color='g', marker='o', linestyle="--" , label='Total_Exports')

# Añadir título y etiquetas
plt.title('Comparación de Total Ventas y Total Exportacion por Producto')
plt.xlabel('Producto')
plt.xticks(rotation=45)  # Rotar etiquetas de producto para mejor visualización
plt.ylabel('Cantidad Total ($) en Millones')
plt.legend()
plt.grid(axis='both')


# Ajustar los límites y los ticks del eje y
max_value = max(df_ventas_vs_exportaciones_ordenado["Total_ventas"].max(), df_ventas_vs_exportaciones_ordenado["Total_Exports"].max())
#plt.ylim( 0 , max_value * 1.1)  # Añadir un 10% de espacio arriba del valor máximo

# Configurar los ticks del eje y
plt.yticks(range(0, int(max_value) + 5000, 5000))

# Formateo del eje Y para mejor visualización
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f'{x :,.0f}'))

#Gráficar
plt.tight_layout()
plt.show()
